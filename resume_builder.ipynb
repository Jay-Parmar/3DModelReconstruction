# %%
from docx import Document

# Create a new Document
doc = Document()
doc.add_heading('Jay Parmar', level=1)

# Contact Information
doc.add_heading('Contact', level=2)
contact_info = [
    "Mobile: 9039119542",
    "Email: jayparmar789@gmail.com",
    "LinkedIn: www.linkedin.com/in/jay-parmar-879138185/"
]
for info in contact_info:
    doc.add_paragraph(info)

# Professional Summary
doc.add_heading('Objective', level=2)
summary = (
    "Highly skilled and motivated software developer with experience in all stages of advanced "
    "web development, from concept through delivery and optimization. Proficient in user interface "
    "design, testing, debugging processes, and scaling applications to meet the demand of growing businesses. "
    "Seeking to leverage expertise in the development of innovative software solutions with a forward-thinking company."
)
doc.add_paragraph(summary)

# Education
doc.add_heading('Education', level=2)
education = (
    "Rungta College of Engineering and Technology, Bhilai\n"
    "B.Tech (CSE), 2018 - 2022\n"
    "GPA: 8.2"
)
doc.add_paragraph(education)

# Skills
doc.add_heading('Skills', level=2)
skills = [
    "Django Rest Framework (Python)",
    "AngularJS",
    "ReactJS",
    "PostgreSQL/MySQL",
    "Git",
    "Jira (PM tool with API integration)",
    "Problem Solving",
    "Team Collaboration"
]
for skill in skills:
    doc.add_paragraph(skill, style='List Bullet')

# Experience
doc.add_heading('Experience', level=2)
experiences = [
    {
        'title': 'Software Developer, Josh Technology Group',
        'date': 'July 2022—August 2023',
        'points': [
            "Led Full Stack development projects, enhancing product functionality for over 200,000 daily users.",
            "Collaborated with cross-functional teams to integrate diverse components seamlessly.",
            "Optimized application performance, resulting in a 10% reduction in API load times."
        ]
    },
    {
        'title': 'Software Development Intern, Josh Technology Group',
        'date': 'September 2021—June 2022',
        'points': [
            "Implemented new features and technologies, contributing to major projects and improving system reusability and quality.",
            "Gained hands-on experience in fast-paced development environments, adapting quickly to new challenges."
        ]
    }
]
for experience in experiences:
    doc.add_paragraph(f"{experience['title']} • {experience['date']}", style='List Bullet')
    for point in experience['points']:
        doc.add_paragraph(point, style='List Bullet 2')

# Projects
doc.add_heading('Projects', level=2)
projects = [
    {
        'name': 'Poker Planner',
        'description': (
            "A real-time corporate game allowing players to estimate tickets in Jira. "
            "Technologies used: AngularJS, Django Rest Framework, PostgreSQL."
        )
    },
    {
        'name': 'Article Bay',
        'description': (
            "Dynamic blogging platform to facilitate seamless content publication. "
            "Technologies used: AngularJS, Django Rest Framework, PostgreSQL."
        )
    }
]
for project in projects:
    doc.add_paragraph(project['name'], style='List Bullet')
    doc.add_paragraph(project['description'], style='List Bullet 2')

# Save the document
resume_path = '/mnt/data/Jay_Parmar_Resume_Updated.docx'
doc.save(resume_path)
resume_path
